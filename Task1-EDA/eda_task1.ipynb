# %%
# Task 1 – Exploratory Data Analysis (EDA)
# Internship: NAIC Data Science Internship 2025
# Dataset: college_student_placement_dataset.csv

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("D:/internship/archive (5)/college_student_placement_dataset.csv")
print("✅ Dataset loaded successfully!\n")

# Show dataset shape and columns
print("📏 Shape:", df.shape)
print("\n🧾 Column names:")
print(df.columns.tolist())

# Display first 5 rows
print("\n🔍 Preview of dataset:")
display(df.head())

# Data types and non-null counts
print("\n📄 Dataset Info:")
df.info()

# Check for missing values
print("\n❗ Missing values per column:")
print(df.isnull().sum())

# Summary statistics
print("\n📊 Summary Statistics:")
print(df.describe(include='all'))

# 🔍 Step: Check unique values in each column
print("\n🔍 Unique values in each column (to detect placement column):")
for col in df.columns:
    print(f"{col}: {df[col].unique()[:10]}")  # show only first 10 unique values

# Manually define placement status column if known
# You can change this name based on what print(df.columns) showed
status_col = 'status'  # ← change if it's different like 'Placed' or 'Placement_Status'

if status_col in df.columns:
    # Placement status count
    sns.countplot(x=status_col, data=df, palette='Set2')
    plt.title("Placement Status Count")
    plt.show()

    # Gender vs Placement
    sns.countplot(x='gender', hue=status_col, data=df, palette='coolwarm')
    plt.title("Placement by Gender")
    plt.show()

    # Specialisation vs Placement
    plt.figure(figsize=(10, 5))
    sns.countplot(x='specialisation', hue=status_col, data=df, palette='magma')
    plt.title("Specialisation vs Placement")
    plt.xticks(rotation=30)
    plt.show()

    # Degree percentage vs Placement
    plt.figure(figsize=(8, 5))
    sns.histplot(data=df, x='degree_p', hue=status_col, kde=True)
    plt.title("Degree Percentage vs Placement")
    plt.show()

    # E-test score vs Placement
    plt.figure(figsize=(8, 5))
    sns.histplot(data=df, x='etest_p', hue=status_col, kde=True)
    plt.title("E-test Score vs Placement")
    plt.show()
else:
    print(f"\n⚠️ Column '{status_col}' not found in dataset. Skipping placement visualizations.")

# Work experience
if 'workex' in df.columns:
    sns.countplot(x='workex', data=df, palette='Accent')
    plt.title("Work Experience Distribution")
    plt.show()

# Correlation heatmap (numeric columns only)
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='YlGnBu')
plt.title("Correlation Heatmap")
plt.show()

# ✅ Summary
print("\n✅ Task 1 – EDA Completed.")
print("\n📌 Suggested Insights:")
print("1. Degree percentage and MBA scores impact placement chances.")
print("2. Gender and specialisation also influence placement trends.")
print("3. Candidates with work experience may have higher placement rates.")
# Out:
# ✅ Dataset loaded successfully!
#
# 📏 Shape: (10000, 10)
#
# 🧾 Column names:
# ['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance', 'Internship_Experience', 'Extra_Curricular_Score', 'Communication_Skills', 'Projects_Completed', 'Placement']
#
# 🔍 Preview of dataset:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# 3                   1        No
# 4                   2        No
# 📄 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB
#
# ❗ Missing values per column:
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64
#
# 📊 Summary Statistics:
#        College_ID            IQ  Prev_Sem_Result          CGPA  \
# count       10000  10000.000000     10000.000000  10000.000000
# unique        100           NaN              NaN           NaN
# top       CLG0062           NaN              NaN           NaN
# freq          133           NaN              NaN           NaN
# mean          NaN     99.471800         7.535673      7.532379
# std           NaN     15.053101         1.447519      1.470141
# min           NaN     41.000000         5.000000      4.540000
# 25%           NaN     89.000000         6.290000      6.290000
# 50%           NaN     99.000000         7.560000      7.550000
# 75%           NaN    110.000000         8.790000      8.770000
# max           NaN    158.000000        10.000000     10.460000
#
#         Academic_Performance Internship_Experience  Extra_Curricular_Score  \
# count           10000.000000                 10000            10000.000000
# unique                   NaN                     2                     NaN
# top                      NaN                    No                     NaN
# freq                     NaN                  6036                     NaN
# mean                5.546400                   NaN                4.970900
# std                 2.873477                   NaN                3.160103
# min                 1.000000                   NaN                0.000000
# 25%                 3.000000                   NaN                2.000000
# 50%                 6.000000                   NaN                5.000000
# 75%                 8.000000                   NaN                8.000000
# max                10.000000                   NaN               10.000000
#
#         Communication_Skills  Projects_Completed Placement
# count           10000.000000        10000.000000     10000
# unique                   NaN                 NaN         2
# top                      NaN                 NaN        No
# freq                     NaN                 NaN      8341
# mean                5.561800            2.513400       NaN
# std                 2.900866            1.715959       NaN
# min                 1.000000            0.000000       NaN
# 25%                 3.000000            1.000000       NaN
# 50%                 6.000000            3.000000       NaN
# 75%                 8.000000            4.000000       NaN
# max                10.000000            5.000000       NaN
#
# 🔍 Unique values in each column (to detect placement column):
# College_ID: ['CLG0030' 'CLG0061' 'CLG0036' 'CLG0055' 'CLG0004' 'CLG0015' 'CLG0071'
#  'CLG0096' 'CLG0097' 'CLG0057']
# IQ: [107  97 109 122  96 123 111  92 108  93]
# Prev_Sem_Result: [6.61 5.52 5.36 5.47 7.91 5.26 6.68 8.77 6.47 8.82]
# CGPA: [6.28 5.37 5.83 5.75 7.69 5.32 6.58 8.76 6.33 8.6 ]
# Academic_Performance: [ 8  9  6  7  5  4  2  3 10  1]
# Internship_Experience: ['No' 'Yes']
# Extra_Curricular_Score: [ 8  7  3  1  5  0  4  9  2 10]
# Communication_Skills: [ 8  1  6 10  9  7  5  2  3  4]
# Projects_Completed: [4 0 1 2 5 3]
# Placement: ['No' 'Yes']
#
# ⚠️ Column 'status' not found in dataset. Skipping placement visualizations.
# ✅ Task 1 – EDA Completed.
#
# 📌 Suggested Insights:
# 1. Degree percentage and MBA scores impact placement chances.
# 2. Gender and specialisation also influence placement trends.
# 3. Candidates with work experience may have higher placement rates.
